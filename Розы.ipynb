# %%
import matplotlib.pyplot as plt
import numpy as np
import math

plt.figure(figsize = (7, 7))

phi = np.linspace(0, 6*np.pi, 400)

rho = 0.75*abs(np.cos(5/3 * phi))

z = rho * (np.cos(phi) + 1j * np.sin(phi))

#plt.subplot(121)

#plt.plot(z.real, z.imag)

#plt.xlabel("Re(z)")
#plt.ylabel("Im(z)")

#plt.subplot(122, projection = 'polar')

plt.polar(phi, rho, linewidth = 0.8)

phi_1 = np.linspace(-np.pi/10, np.pi/10, 50)
rho = 0.75*abs(np.cos(5/3 * phi_1))
plt.polar(phi_1, rho, color = 'black', linewidth = 2)

phi_2 = np.linspace((-np.pi/10 + 3/5 * np.pi), (np.pi/10 + 3/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_2))
plt.polar(phi_2, rho, color = 'black', linewidth = 2)

phi_3 = np.linspace((-np.pi/10 + 6/5 * np.pi), (np.pi/10 + 6/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_3))
plt.polar(phi_3, rho, color = 'black', linewidth = 2)

phi_4 = np.linspace((-np.pi/10 + 9/5 * np.pi), (np.pi/10 + 9/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_4))
plt.polar(phi_4, rho, color = 'black', linewidth = 2)

phi_5 = np.linspace((-np.pi/10 + 12/5 * np.pi), (np.pi/10 + 12/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_5))
plt.polar(phi_5, rho, color = 'black', linewidth = 2)

phi_6 = np.linspace((-np.pi/10 + 15/5 * np.pi), (np.pi/10 + 15/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_6))
plt.polar(phi_6, rho, color = 'black', linewidth = 2)

phi_7 = np.linspace((-np.pi/10 + 18/5 * np.pi), (np.pi/10 + 18/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_7))
plt.polar(phi_7, rho, color = 'black', linewidth = 2)

phi_8 = np.linspace((-np.pi/10 + 21/5 * np.pi), (np.pi/10 + 21/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_8))
plt.polar(phi_8, rho, color = 'black', linewidth = 2)

phi_9 = np.linspace((-np.pi/10 + 24/5 * np.pi), (np.pi/10 + 24/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_9))
plt.polar(phi_9, rho, color = 'black', linewidth = 2)

phi_10 = np.linspace((-np.pi/10 + 27/5 * np.pi), (np.pi/10 + 27/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_10))
plt.polar(phi_10, rho, color = 'black', linewidth = 2)

ax = plt.gca()
ax.get_yaxis().set_visible(False)
ax.get_xaxis().set_visible(False)

dist = np.linspace(0, 0.8, 31)    #концентрические окружности
rad = []
for i in range(31):
    rad.append(dist)
theta = np.linspace(0, 0, 31)
alpha = []
for i in range(31):
    alpha.append(theta + i*np.pi/15)

plt.polar(alpha, rad, color = 'black', linewidth = 0.2)

dist = np.linspace(0, 0.8, 31)   #лучи из нуля
rad = dist
theta = np.linspace(0, 2*np.pi, 31)
alpha = []
for i in range(31):
    alpha.append(theta)

plt.polar(alpha, rad, color = 'black', linewidth = 0.2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

plt.figure(figsize = (7, 7))

phi = np.linspace(0, 6*np.pi, 400)

rho = 0.75*abs(np.cos(5/3 * phi))

z = rho * (np.cos(phi) + 1j * np.sin(phi)) 

#plt.subplot(121)

f = np.arcsinh(z)

#plt.plot(f.real, f.imag)

#plt.xlabel("Re(z)")
#plt.ylabel("Im(z)")

#plt.subplot(122, projection = 'polar')

f = np.arcsinh(0.75*abs(np.cos(5/3 * phi)))

plt.polar(phi, f, linewidth = 0.8)

phi_1 = np.linspace(-np.pi/10, np.pi/10, 50)
f = np.arcsinh(0.75*abs(np.cos(5/3 * phi_1)))
plt.polar(phi_1, f, color = 'black', linewidth = 2)

phi_2 = np.linspace((-np.pi/10 + 3/5 * np.pi), (np.pi/10 + 3/5 * np.pi), 50)
f = np.arcsinh(0.75*abs(np.cos(5/3 * phi_2)))
plt.polar(phi_2, f, color = 'black', linewidth = 2)

phi_3 = np.linspace((-np.pi/10 + 6/5 * np.pi), (np.pi/10 + 6/5 * np.pi), 50)
f = np.arcsinh(0.75*abs(np.cos(5/3 * phi_3)))
plt.polar(phi_3, f, color = 'black', linewidth = 2)

phi_4 = np.linspace((-np.pi/10 + 9/5 * np.pi), (np.pi/10 + 9/5 * np.pi), 50)
f = np.arcsinh(0.75*abs(np.cos(5/3 * phi_4)))
plt.polar(phi_4, f, color = 'black', linewidth = 2)

phi_5 = np.linspace((-np.pi/10 + 12/5 * np.pi), (np.pi/10 + 12/5 * np.pi), 50)
f = np.arcsinh(0.75*abs(np.cos(5/3 * phi_5)))
plt.polar(phi_5, f, color = 'black', linewidth = 2)

phi_6 = np.linspace((-np.pi/10 + 15/5 * np.pi), (np.pi/10 + 15/5 * np.pi), 50)
f = np.arcsinh(0.75*abs(np.cos(5/3 * phi_6)))
plt.polar(phi_6, f, color = 'black', linewidth = 2)

phi_7 = np.linspace((-np.pi/10 + 18/5 * np.pi), (np.pi/10 + 18/5 * np.pi), 50)
f = np.arcsinh(0.75*abs(np.cos(5/3 * phi_7)))
plt.polar(phi_7, f, color = 'black', linewidth = 2)

phi_8 = np.linspace((-np.pi/10 + 21/5 * np.pi), (np.pi/10 + 21/5 * np.pi), 50)
f = np.arcsinh(0.75*abs(np.cos(5/3 * phi_8)))
plt.polar(phi_8, f, color = 'black', linewidth = 2)

phi_9 = np.linspace((-np.pi/10 + 24/5 * np.pi), (np.pi/10 + 24/5 * np.pi), 50)
f = np.arcsinh(0.75*abs(np.cos(5/3 * phi_9)))
plt.polar(phi_9, f, color = 'black', linewidth = 2)

phi_10 = np.linspace((-np.pi/10 + 27/5 * np.pi), (np.pi/10 + 27/5 * np.pi), 50)
f = np.arcsinh(0.75*abs(np.cos(5/3 * phi_10)))
plt.polar(phi_10, f, color = 'black', linewidth = 2)

ax = plt.gca()
ax.get_yaxis().set_visible(False)
ax.get_xaxis().set_visible(False)

dist = np.linspace(0, 0.8, 31)
rad = []
for i in range(31):
    rad.append(np.arcsinh(dist))
theta = np.linspace(0, 0, 31)
alpha = []
for i in range(31):
    alpha.append(theta + i*np.pi/15)

plt.polar(alpha, rad, color = 'black', linewidth = 0.3)

dist = np.linspace(0, 0.8, 31)
rad = np.arcsinh(dist)
theta = np.linspace(0, 2*np.pi, 31)
alpha = []
for i in range(31):
    alpha.append(theta)
#rad = np.arcsinh(dist*(np.cos(theta) + 1j * np.sin(theta)))

plt.polar(alpha, rad, color = 'black', linewidth = 0.3)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

plt.figure(figsize = (8, 8))

#зададим аргумент и модуль комплексного числа
phi = np.linspace(0, 6*np.pi, 400)

rho = 0.75*abs(np.cos(5/3 * phi))

z = rho * (np.cos(phi) + 1j * np.sin(phi))

#построение исходной розы
plt.plot(z.real, z.imag, color = 'red', linewidth = 0.8)

plt.xlabel("Re(z)")
plt.ylabel("Im(z)")

#построение границы исходной розы
phi_1 = np.linspace(-np.pi/10, np.pi/10, 50)
rho = 0.75*abs(np.cos(5/3 * phi_1))
z = rho * (np.cos(phi_1) + 1j * np.sin(phi_1))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_2 = np.linspace((-np.pi/10 + 3/5 * np.pi), (np.pi/10 + 3/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_2))
z = rho * (np.cos(phi_2) + 1j * np.sin(phi_2))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_3 = np.linspace((-np.pi/10 + 6/5 * np.pi), (np.pi/10 + 6/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_3))
z = rho * (np.cos(phi_3) + 1j * np.sin(phi_3))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_4 = np.linspace((-np.pi/10 + 9/5 * np.pi), (np.pi/10 + 9/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_4))
z = rho * (np.cos(phi_4) + 1j * np.sin(phi_4))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_5 = np.linspace((-np.pi/10 + 12/5 * np.pi), (np.pi/10 + 12/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_5))
z = rho * (np.cos(phi_5) + 1j * np.sin(phi_5))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_6 = np.linspace((-np.pi/10 + 15/5 * np.pi), (np.pi/10 + 15/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_6))
z = rho * (np.cos(phi_6) + 1j * np.sin(phi_6))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_7 = np.linspace((-np.pi/10 + 18/5 * np.pi), (np.pi/10 + 18/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_7))
z = rho * (np.cos(phi_7) + 1j * np.sin(phi_7))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_8 = np.linspace((-np.pi/10 + 21/5 * np.pi), (np.pi/10 + 21/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_8))
z = rho * (np.cos(phi_8) + 1j * np.sin(phi_8))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_9 = np.linspace((-np.pi/10 + 24/5 * np.pi), (np.pi/10 + 24/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_9))
z = rho * (np.cos(phi_9) + 1j * np.sin(phi_9))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_10 = np.linspace((-np.pi/10 + 27/5 * np.pi), (np.pi/10 + 27/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_10))
z = rho * (np.cos(phi_10) + 1j * np.sin(phi_10))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

#построение координатной сетки до отображения
x = np.linspace(-1, 1, 50)
y = np.linspace(0, 0, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(0.2, 0.2, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(0.4, 0.4, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(0.6, 0.6, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(0.8, 0.8, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(-0.2, -0.2, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(-0.4, -0.4, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(-0.6, -0.6, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(-0.8, -0.8, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0, 0, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0.25, 0.25, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0.5, 0.5, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0.75, 0.75, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-0.25, -0.25, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-0.5, -0.5, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-0.75, -0.75, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

plt.xlim(-1, 1)
plt.ylim(-0.85, 0.85)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

plt.figure(figsize = (8, 8))

#модуль, аргумент и отображение комплексного числа
phi = np.linspace(0, 6*np.pi, 400)

rho = 0.75*abs(np.cos(5/3 * phi))

z = rho * (np.cos(phi) + 1j * np.sin(phi)) 

f = np.arcsinh(z)

#построение образа розы
plt.plot(f.real, f.imag, color = 'orange', linewidth = 0.8)

plt.xlabel("Re(f(z))")
plt.ylabel("Im(f(z))")

#построение образа границы розы
phi_1 = np.linspace(-np.pi/10, np.pi/10, 50)
rho = 0.75*abs(np.cos(5/3 * phi_1))
z = rho * (np.cos(phi_1) + 1j * np.sin(phi_1))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_2 = np.linspace((-np.pi/10 + 3/5 * np.pi), (np.pi/10 + 3/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_2))
z = rho * (np.cos(phi_2) + 1j * np.sin(phi_2))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_3 = np.linspace((-np.pi/10 + 6/5 * np.pi), (np.pi/10 + 6/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_3))
z = rho * (np.cos(phi_3) + 1j * np.sin(phi_3))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_4 = np.linspace((-np.pi/10 + 9/5 * np.pi), (np.pi/10 + 9/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_4))
z = rho * (np.cos(phi_4) + 1j * np.sin(phi_4))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_5 = np.linspace((-np.pi/10 + 12/5 * np.pi), (np.pi/10 + 12/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_5))
z = rho * (np.cos(phi_5) + 1j * np.sin(phi_5))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_6 = np.linspace((-np.pi/10 + 15/5 * np.pi), (np.pi/10 + 15/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_6))
z = rho * (np.cos(phi_6) + 1j * np.sin(phi_6))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_7 = np.linspace((-np.pi/10 + 18/5 * np.pi), (np.pi/10 + 18/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_7))
z = rho * (np.cos(phi_7) + 1j * np.sin(phi_7))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_8 = np.linspace((-np.pi/10 + 21/5 * np.pi), (np.pi/10 + 21/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_8))
z = rho * (np.cos(phi_8) + 1j * np.sin(phi_8))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_9 = np.linspace((-np.pi/10 + 24/5 * np.pi), (np.pi/10 + 24/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_9))
z = rho * (np.cos(phi_9) + 1j * np.sin(phi_9))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_10 = np.linspace((-np.pi/10 + 27/5 * np.pi), (np.pi/10 + 27/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_10))
z = rho * (np.cos(phi_10) + 1j * np.sin(phi_10))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

#построение новой координатной сетки
x = np.linspace(-2, 2, 50)
y = np.linspace(0, 0, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(0.2, 0.2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(0.4, 0.4, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(0.6, 0.6, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(0.8, 0.8, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(-0.2, -0.2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(-0.4, -0.4, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(-0.6, -0.6, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(-0.8, -0.8, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0, 0, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0.25, 0.25, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0.5, 0.5, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0.75, 0.75, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-0.25, -0.25, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-0.5, -0.5, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-0.75, -0.75, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

plt.xlim(-1, 1)
plt.ylim(-0.85, 0.85)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

plt.figure(figsize = (8, 8))

phi = np.linspace(0, 2*np.pi, 400)

rho_1 = 0.5*abs(np.cos(3/2 * phi))

z = rho_1 * (np.cos(phi) + 1j * np.sin(phi))

plt.plot(z.real, z.imag, color = 'red', linewidth = 0.8)

phi = np.linspace(0, 6*np.pi, 400)

rho_2 = 0.2*abs(np.cos(1/6 * phi))

z = rho_2 * (np.cos(phi) + 1j * np.sin(phi))

plt.plot(z.real, z.imag, color = 'orange', linewidth = 0.8)  #оставить контур и закрасить

plt.xlabel("Re(z)")
plt.ylabel("Im(z)")

plt.xlim(-0.6, 0.6)
plt.ylim(-0.6, 0.6)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

plt.figure(figsize = (8, 8))

phi = np.linspace(0, 2*np.pi, 400)

rho_1 = 0.5*abs(np.cos(3/2 * phi))

z = rho_1 * (np.cos(phi) + 1j * np.sin(phi))

g = np.tanh(z)

plt.plot(g.real, g.imag, color = 'red', linewidth = 0.8)

phi = np.linspace(0, 6*np.pi, 400)

rho_2 = 0.2*abs(np.cos(1/6 * phi))

z = rho_2 * (np.cos(phi) + 1j * np.sin(phi))

g = np.tanh(z)

plt.plot(g.real, g.imag, color = 'orange', linewidth = 0.8)

plt.xlabel("Re(g(z))")
plt.ylabel("Im(g(z))")

plt.xlim(-0.6, 0.6)
plt.ylim(-0.6, 0.6)

plt.show()
