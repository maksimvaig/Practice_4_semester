# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (8, 8))

#зададим аргумент и модуль комплексного числа
phi = np.linspace(0, 6*np.pi, 400)
rho = 0.75*abs(np.cos(5/3 * phi))
z = rho * (np.cos(phi) + 1j * np.sin(phi))

#построение исходной розы
plt.plot(z.real, z.imag, color = 'red', linewidth = 0.8)

plt.xlabel("Re(z)")
plt.ylabel("Im(z)")

#построение границы исходной розы
phi_1 = np.linspace(-np.pi/10, np.pi/10, 50)
rho = 0.75*abs(np.cos(5/3 * phi_1))
z = rho * (np.cos(phi_1) + 1j * np.sin(phi_1))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_2 = np.linspace((-np.pi/10 + 3/5 * np.pi), (np.pi/10 + 3/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_2))
z = rho * (np.cos(phi_2) + 1j * np.sin(phi_2))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_3 = np.linspace((-np.pi/10 + 6/5 * np.pi), (np.pi/10 + 6/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_3))
z = rho * (np.cos(phi_3) + 1j * np.sin(phi_3))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_4 = np.linspace((-np.pi/10 + 9/5 * np.pi), (np.pi/10 + 9/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_4))
z = rho * (np.cos(phi_4) + 1j * np.sin(phi_4))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_5 = np.linspace((-np.pi/10 + 12/5 * np.pi), (np.pi/10 + 12/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_5))
z = rho * (np.cos(phi_5) + 1j * np.sin(phi_5))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_6 = np.linspace((-np.pi/10 + 15/5 * np.pi), (np.pi/10 + 15/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_6))
z = rho * (np.cos(phi_6) + 1j * np.sin(phi_6))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_7 = np.linspace((-np.pi/10 + 18/5 * np.pi), (np.pi/10 + 18/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_7))
z = rho * (np.cos(phi_7) + 1j * np.sin(phi_7))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_8 = np.linspace((-np.pi/10 + 21/5 * np.pi), (np.pi/10 + 21/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_8))
z = rho * (np.cos(phi_8) + 1j * np.sin(phi_8))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_9 = np.linspace((-np.pi/10 + 24/5 * np.pi), (np.pi/10 + 24/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_9))
z = rho * (np.cos(phi_9) + 1j * np.sin(phi_9))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

phi_10 = np.linspace((-np.pi/10 + 27/5 * np.pi), (np.pi/10 + 27/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_10))
z = rho * (np.cos(phi_10) + 1j * np.sin(phi_10))
plt.plot(z.real, z.imag, color = 'red', linewidth = 3)

#построение координатной сетки до отображения
x = np.linspace(-1, 1, 50)
y = np.linspace(0, 0, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(0.2, 0.2, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(0.4, 0.4, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(0.6, 0.6, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(0.8, 0.8, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(-0.2, -0.2, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(-0.4, -0.4, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(-0.6, -0.6, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, 1, 50)
y = np.linspace(-0.8, -0.8, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0, 0, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0.25, 0.25, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0.5, 0.5, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0.75, 0.75, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-0.25, -0.25, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-0.5, -0.5, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-0.75, -0.75, 50)
y = np.linspace(-0.85, 0.85, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

plt.xlim(-1, 1)
plt.ylim(-0.85, 0.85)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (8, 8))

#модуль, аргумент и отображение комплексного числа
phi = np.linspace(0, 6*np.pi, 400)
rho = 0.75*abs(np.cos(5/3 * phi))
z = rho * (np.cos(phi) + 1j * np.sin(phi)) 
f = np.arcsinh(z)

#построение образа розы
plt.plot(f.real, f.imag, color = 'orange', linewidth = 0.8)

plt.xlabel("Re(f(z))")
plt.ylabel("Im(f(z))")

#построение образа границы розы
phi_1 = np.linspace(-np.pi/10, np.pi/10, 50)
rho = 0.75*abs(np.cos(5/3 * phi_1))
z = rho * (np.cos(phi_1) + 1j * np.sin(phi_1))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_2 = np.linspace((-np.pi/10 + 3/5 * np.pi), (np.pi/10 + 3/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_2))
z = rho * (np.cos(phi_2) + 1j * np.sin(phi_2))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_3 = np.linspace((-np.pi/10 + 6/5 * np.pi), (np.pi/10 + 6/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_3))
z = rho * (np.cos(phi_3) + 1j * np.sin(phi_3))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_4 = np.linspace((-np.pi/10 + 9/5 * np.pi), (np.pi/10 + 9/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_4))
z = rho * (np.cos(phi_4) + 1j * np.sin(phi_4))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_5 = np.linspace((-np.pi/10 + 12/5 * np.pi), (np.pi/10 + 12/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_5))
z = rho * (np.cos(phi_5) + 1j * np.sin(phi_5))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_6 = np.linspace((-np.pi/10 + 15/5 * np.pi), (np.pi/10 + 15/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_6))
z = rho * (np.cos(phi_6) + 1j * np.sin(phi_6))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_7 = np.linspace((-np.pi/10 + 18/5 * np.pi), (np.pi/10 + 18/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_7))
z = rho * (np.cos(phi_7) + 1j * np.sin(phi_7))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_8 = np.linspace((-np.pi/10 + 21/5 * np.pi), (np.pi/10 + 21/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_8))
z = rho * (np.cos(phi_8) + 1j * np.sin(phi_8))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_9 = np.linspace((-np.pi/10 + 24/5 * np.pi), (np.pi/10 + 24/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_9))
z = rho * (np.cos(phi_9) + 1j * np.sin(phi_9))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

phi_10 = np.linspace((-np.pi/10 + 27/5 * np.pi), (np.pi/10 + 27/5 * np.pi), 50)
rho = 0.75*abs(np.cos(5/3 * phi_10))
z = rho * (np.cos(phi_10) + 1j * np.sin(phi_10))
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'orange', linewidth = 3)

#построение новой координатной сетки
x = np.linspace(-2, 2, 50)
y = np.linspace(0, 0, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(0.2, 0.2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(0.4, 0.4, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(0.6, 0.6, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(0.8, 0.8, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(-0.2, -0.2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(-0.4, -0.4, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(-0.6, -0.6, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, 2, 50)
y = np.linspace(-0.8, -0.8, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0, 0, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0.25, 0.25, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0.5, 0.5, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0.75, 0.75, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-0.25, -0.25, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-0.5, -0.5, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-0.75, -0.75, 50)
y = np.linspace(-2, 2, 50)
z = x + 1j * y
f = np.arcsinh(z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

plt.xlim(-1, 1)
plt.ylim(-0.85, 0.85)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (8, 8))

#раскраска 1 зоны (справа)
x_1 = np.linspace(0.13, 0.18, 201)
x = []
for i in range(201):
    x.append(x_1)
y_1 = np.linspace(-0.19, -0.19, 201)
y = []
for i in range(201):
    y.append(y_1 + i/200*2*0.19)
plt.plot(x, y, color = 'lightgreen')

x_2 = np.linspace(0.18, 0.23, 201)
x = []
for i in range(201):
    x.append(x_2)
plt.plot(x, y, color = 'lime')

x_3 = np.linspace(0.23, 0.30, 201)
x = []
for i in range(201):
    x.append(x_3)
plt.plot(x, y, color = 'limegreen')

x_4 = np.linspace(0.30, 0.37, 201)
x = []
for i in range(201):
    x.append(x_4)
plt.plot(x, y, color = 'forestgreen')

x_5 = np.linspace(0.37, 0.44, 201)
x = []
for i in range(201):
    x.append(x_5)
plt.plot(x, y, color = 'green')

x_6 = np.linspace(0.44, 0.51, 201)
x = []
for i in range(201):
    x.append(x_6)
plt.plot(x, y, color = 'darkgreen')



#раскраска 2 зоны (слева вверху)
x_7 = np.linspace(-0.34, -0.28, 201)
x = []
for i in range(201):
    x.append(x_7)
y_2 = np.linspace(0.043, 0.043, 201)
y = []
for i in range(201):
    y.append(y_2 + i/200*(0.465 - 0.043))
plt.plot(x, y, color = 'darkred')

x_8 = np.linspace(-0.28, -0.22, 201)
x = []
for i in range(201):
    x.append(x_8)
plt.plot(x, y, color = 'firebrick')

x_9 = np.linspace(-0.22, -0.15, 201)
x = []
for i in range(201):
    x.append(x_9)
plt.plot(x, y, color = 'red')

x_10 = np.linspace(-0.15, -0.08, 201)
x = []
for i in range(201):
    x.append(x_10)
plt.plot(x, y, color = 'tomato')

x_11 = np.linspace(-0.08, -0.01, 201)
x = []
for i in range(201):
    x.append(x_11)
plt.plot(x, y, color = 'salmon')

x_12 = np.linspace(-0.01, 0.06, 201)
x = []
for i in range(201):
    x.append(x_12)
plt.plot(x, y, color = 'lightsalmon')



#раскраска 3 зоны (слева внизу)
x = []
for i in range(201):
    x.append(x_7)
y_3 = np.linspace(-0.465, -0.465, 201)
y = []
for i in range(201):
    y.append(y_3 + i/200*(0.465 - 0.043))
plt.plot(x, y, color = 'darkblue')

x = []
for i in range(201):
    x.append(x_8)
plt.plot(x, y, color = 'mediumblue')

x = []
for i in range(201):
    x.append(x_9)
plt.plot(x, y, color = 'blue')

x = []
for i in range(201):
    x.append(x_10)
plt.plot(x, y, color = 'dodgerblue')

x = []
for i in range(201):
    x.append(x_11)
plt.plot(x, y, color = 'cornflowerblue')

x = []
for i in range(201):
    x.append(x_12)
plt.plot(x, y, color = 'lightsteelblue')


#построение меньшей границы
phi = np.linspace(0, 6*np.pi, 400)
rho_1 = 0.2*abs(np.cos(1/6 * phi))
z = rho_1 * (np.cos(phi) + 1j * np.sin(phi))
plt.plot(z.real, z.imag, color = 'black', linewidth = 2)

#построение большей границы
phi = np.linspace(0, 2*np.pi, 400)
rho_2 = 0.5*abs(np.cos(3/2 * phi))
z = rho_2 * (np.cos(phi) + 1j * np.sin(phi))
plt.plot(z.real, z.imag, color = 'orange', linewidth = 2) 

#построение границы заданной области
phi_1 = np.linspace(-0.7753, 0.7753, 100)
rho_1 = 0.2*abs(np.cos(1/6 * phi_1))
z = rho_1 * (np.cos(phi_1) + 1j * np.sin(phi_1))
plt.plot(z.real, z.imag, color = 'gray', linewidth = 3.5)

rho_2 = 0.5*abs(np.cos(3/2 * phi_1))
z = rho_2 * (np.cos(phi_1) + 1j * np.sin(phi_1))
plt.plot(z.real, z.imag, color = 'gray', linewidth = 3.5)

phi_2 = np.linspace((-0.7753 + 2*np.pi/3), (0.7753 + 2*np.pi/3), 100)
rho_1 = 0.2*abs(np.cos(1/6 * phi_2))
z = rho_1 * (np.cos(phi_2) + 1j * np.sin(phi_2))
plt.plot(z.real, z.imag, color = 'gray', linewidth = 3.5)

phi_2 = np.linspace((-0.7753 + 2*np.pi/3), (0.8 + 2*np.pi/3), 100)
rho_2 = 0.5*abs(np.cos(3/2 * phi_2))
z = rho_2 * (np.cos(phi_2) + 1j * np.sin(phi_2))
plt.plot(z.real, z.imag, color = 'gray', linewidth = 3.5)

phi_3 = np.linspace((-0.7753 - 2*np.pi/3), (0.7753 - 2*np.pi/3), 100)
rho_1 = 0.2*abs(np.cos(1/6 * phi_3))
z = rho_1 * (np.cos(phi_3) + 1j * np.sin(phi_3))
plt.plot(z.real, z.imag, color = 'gray', linewidth = 3.5)

phi_3 = np.linspace((-0.8 - 2*np.pi/3), (0.7753 - 2*np.pi/3), 100)
rho_2 = 0.5*abs(np.cos(3/2 * phi_3))
z = rho_2 * (np.cos(phi_3) + 1j * np.sin(phi_3))
plt.plot(z.real, z.imag, color = 'gray', linewidth = 3.5)

plt.xlabel("Re(z)")
plt.ylabel("Im(z)")

plt.xlim(-0.6, 0.6)
plt.ylim(-0.6, 0.6)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (8, 8))

#раскраска образа 1 зоны (справа)
x_1 = np.linspace(0.13, 0.18, 201)
x = []
for i in range(201):
    x.append(x_1)
y_1 = np.linspace(-0.19, -0.19, 201)
y = []
for i in range(201):
    y.append(y_1 + i/200*2*0.19)
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'lightgreen')

x_2 = np.linspace(0.18, 0.23, 201)
x = []
for i in range(201):
    x.append(x_2)
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'lime')

x_3 = np.linspace(0.23, 0.30, 201)
x = []
for i in range(201):
    x.append(x_3)
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'limegreen')

x_4 = np.linspace(0.30, 0.37, 201)
x = []
for i in range(201):
    x.append(x_4)
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'forestgreen')

x_5 = np.linspace(0.37, 0.44, 201)
x = []
for i in range(201):
    x.append(x_5)
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'green')

x_6 = np.linspace(0.44, 0.51, 201)
x = []
for i in range(201):
    x.append(x_6)
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'darkgreen')



#раскраска образа второй зоны (слева вверху)
x_7 = np.linspace(-0.34, -0.28, 201)
x = []
for i in range(201):
    x.append(x_7)
y_2 = np.linspace(0.043, 0.043, 201)
y = []
for i in range(201):
    y.append(y_2 + i/200*(0.465 - 0.043))
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'darkred')

x_8 = np.linspace(-0.28, -0.22, 201)
x = []
for i in range(201):
    x.append(x_8)
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'firebrick')

x_9 = np.linspace(-0.22, -0.15, 201)
x = []
for i in range(201):
    x.append(x_9)
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'red')

x_10 = np.linspace(-0.15, -0.08, 201)
x = []
for i in range(201):
    x.append(x_10)
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'tomato')

x_11 = np.linspace(-0.08, -0.01, 201)
x = []
for i in range(201):
    x.append(x_11)
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'salmon')

x_12 = np.linspace(-0.01, 0.06, 201)
x = []
for i in range(201):
    x.append(x_12)
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'lightsalmon')



#раскраска образа третьей зоны (слева внизу)
x = []
for i in range(201):
    x.append(x_7)
y_3 = np.linspace(-0.465, -0.465, 201)
y = []
for i in range(201):
    y.append(y_3 + i/200*(0.465 - 0.043))
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'darkblue')

x = []
for i in range(201):
    x.append(x_8)
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'mediumblue')

x = []
for i in range(201):
    x.append(x_9)
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'blue')

x = []
for i in range(201):
    x.append(x_10)
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'dodgerblue')

x = []
for i in range(201):
    x.append(x_11)
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'cornflowerblue')

x = []
for i in range(201):
    x.append(x_12)
z_paint = []
for i in range(201):
    for j in range(201):
        z_paint.append(x[i][j] + 1j*y[i][j])
g_z = np.tanh(z_paint)
plt.plot(g_z.real, g_z.imag, color = 'lightsteelblue')


#построение образа меньшей границы
phi = np.linspace(0, 6*np.pi, 400)
rho_1 = 0.2*abs(np.cos(1/6 * phi))
z = rho_1 * (np.cos(phi) + 1j * np.sin(phi))
g = np.tanh(z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 2)

#построение образа большей границы
phi = np.linspace(0, 2*np.pi, 400)
rho_2 = 0.5*abs(np.cos(3/2 * phi))
z = rho_2 * (np.cos(phi) + 1j * np.sin(phi))
g = np.tanh(z)
plt.plot(g.real, g.imag, color = 'orange', linewidth = 2)


#построение образа границы заданной области
phi_1 = np.linspace(-0.7753, 0.7753, 100)
rho_1 = 0.2*abs(np.cos(1/6 * phi_1))
z = rho_1 * (np.cos(phi_1) + 1j * np.sin(phi_1))
g = np.tanh(z)
plt.plot(g.real, g.imag, color = 'gray', linewidth = 3.5)

rho_2 = 0.5*abs(np.cos(3/2 * phi_1))
z = rho_2 * (np.cos(phi_1) + 1j * np.sin(phi_1))
g = np.tanh(z)
plt.plot(g.real, g.imag, color = 'gray', linewidth = 3.5)

phi_2 = np.linspace((-0.7753 + 2*np.pi/3), (0.7753 + 2*np.pi/3), 100)
rho_1 = 0.2*abs(np.cos(1/6 * phi_2))
z = rho_1 * (np.cos(phi_2) + 1j * np.sin(phi_2))
g = np.tanh(z)
plt.plot(g.real, g.imag, color = 'gray', linewidth = 3.5)

phi_2 = np.linspace((-0.7753 + 2*np.pi/3), (0.8 + 2*np.pi/3), 100)
rho_2 = 0.5*abs(np.cos(3/2 * phi_2))
z = rho_2 * (np.cos(phi_2) + 1j * np.sin(phi_2))
g = np.tanh(z)
plt.plot(g.real, g.imag, color = 'gray', linewidth = 3.5)

phi_3 = np.linspace((-0.7753 - 2*np.pi/3), (0.7753 - 2*np.pi/3), 100)
rho_1 = 0.2*abs(np.cos(1/6 * phi_3))
z = rho_1 * (np.cos(phi_3) + 1j * np.sin(phi_3))
g = np.tanh(z)
plt.plot(g.real, g.imag, color = 'gray', linewidth = 3.5)

phi_3 = np.linspace((-0.8 - 2*np.pi/3), (0.7753 - 2*np.pi/3), 100)
rho_2 = 0.5*abs(np.cos(3/2 * phi_3))
z = rho_2 * (np.cos(phi_3) + 1j * np.sin(phi_3))
g = np.tanh(z)
plt.plot(g.real, g.imag, color = 'gray', linewidth = 3.5)

plt.xlabel("Re(g(z))")
plt.ylabel("Im(g(z))")

plt.xlim(-0.6, 0.6)
plt.ylim(-0.6, 0.6)

plt.show()
